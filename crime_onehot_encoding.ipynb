# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('final_dataset/final_model.csv')

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
# encoding independent variable

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [4, 5])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
# ordinal encoding for "Neighborhood" and "Premise"

ct = ColumnTransformer(transformers=[('encoder', OrdinalEncoder(), [6, 7])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
print(X)
# Out:
# [[0.0 0.0 0.0 ... 284.137 215.2 232.978]
#  [0.0 1.0 0.0 ... 284.137 215.2 232.978]
#  [0.0 0.0 0.0 ... 284.137 215.2 232.978]
#  ...
#  [0.0 0.0 0.0 ... 368.791 277.763 300.628]
#  [0.0 0.0 0.0 ... 368.791 277.763 300.628]
#  [0.0 0.0 0.0 ... 368.791 277.763 300.628]]

# %%
# encoding dependent variable

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
print(y)
# Out:
# [ 6  4  6 ... 12 12 12]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
# feature scaling

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-d9a5ae65b4a1> in <module>
#       3 from sklearn.preprocessing import StandardScaler
#       4 sc = StandardScaler()
# ----> 5 X_train = sc.fit_transform(X_train)
#       6 X_test = sc.transform(X_test)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
# ...
