# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('final_dataset/final_model5.csv')

# %%
df.head()
# Out:
#    Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0        2012           12         31   26                      WHITE
# 1        2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2        2012           12         31   25                      WHITE
# 3        2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4        2012           12         31   25                      WHITE
#
#     District    Neighborhood               Premise  Apparel  Commodities  \
# 0   SOUTHERN    FEDERAL HILL                   BAR  118.084      183.077
# 1  NORTHEAST   NEW NORTHWOOD  STREET                118.084      183.077
# 2  SOUTHEAST  GRACELAND PARK     ROW/TOWNHOUSE-OCC  118.084      183.077
# 3   SOUTHERN  HOLLINS MARKET     OTHER/RESIDENTIAL  118.084      183.077
# 4  SOUTHEAST       JONESTOWN  STREET                118.084      183.077
#
#    Education_Communication  Food_Beverage  Housing  Medical_Care  \
# ...

# %%
df["Race"].unique()
# Out:
# array(['WHITE', 'BLACK_OR_AFRICAN_AMERICAN',
#        'AMERICAN_INDIAN_OR_ALASKA_NATIVE', 'ASIAN',
#        'NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER'], dtype=object)

# %%
race = ['BLACK_OR_AFRICAN_AMERICAN', 'WHITE', 'ASIAN', 'AMERICAN_INDIAN_OR_ALASKA_NATIVE', 'NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER']

# %%
enc = OrdinalEncoder(categories = [race])

# %%
enc.fit_transform(df[["Race"]])
# Out:
# array([[1.],
#        [0.],
#        [1.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])

# %%
df[["Race"]] = enc.fit_transform(df[["Race"]])

# %%
df.head()
# Out:
#    Crime_Year  Crime_Month  Crime_Day  Age  Race   District    Neighborhood  \
# 0        2012           12         31   26   1.0   SOUTHERN    FEDERAL HILL
# 1        2012           12         31   34   0.0  NORTHEAST   NEW NORTHWOOD
# 2        2012           12         31   25   1.0  SOUTHEAST  GRACELAND PARK
# 3        2012           12         31   48   0.0   SOUTHERN  HOLLINS MARKET
# 4        2012           12         31   25   1.0  SOUTHEAST       JONESTOWN
#
#                 Premise  Apparel  Commodities  Education_Communication  \
# 0                   BAR  118.084      183.077                  132.662
# 1  STREET                118.084      183.077                  132.662
# 2     ROW/TOWNHOUSE-OCC  118.084      183.077                  132.662
# 3     OTHER/RESIDENTIAL  118.084      183.077                  132.662
# 4  STREET                118.084      183.077                  132.662
#
#    Food_Beverage  Housing  Medical_Care  Other_Goods_Services  Recreation  \
# ...

# %%
df["District"].unique()
# Out:
# array(['SOUTHERN', 'NORTHEAST', 'SOUTHEAST', 'NORTHERN', 'SOUTHWEST',
#        'NORTHWEST', 'CENTRAL', 'WESTERN', 'EASTERN', 'SD5'], dtype=object)

# %%
district = ['NORTHEAST', 'SOUTHEAST', 'CENTRAL', 'NORTHERN', 'SOUTHERN', 'SOUTHWEST', 'NORTHWEST', 'EASTERN', 'WESTERN', 'SD5']

# %%
enc = OrdinalEncoder(categories = [district])

# %%
enc.fit_transform(df[["District"]])
# Out:
# array([[4.],
#        [0.],
#        [1.],
#        ...,
#        [3.],
#        [4.],
#        [4.]])

# %%
df[["District"]] = enc.fit_transform(df[["District"]])

# %%
df.head()
# Out:
#    Crime_Year  Crime_Month  Crime_Day  Age  Race  District    Neighborhood  \
# 0        2012           12         31   26   1.0       4.0    FEDERAL HILL
# 1        2012           12         31   34   0.0       0.0   NEW NORTHWOOD
# 2        2012           12         31   25   1.0       1.0  GRACELAND PARK
# 3        2012           12         31   48   0.0       4.0  HOLLINS MARKET
# 4        2012           12         31   25   1.0       1.0       JONESTOWN
#
#                 Premise  Apparel  Commodities  Education_Communication  \
# 0                   BAR  118.084      183.077                  132.662
# 1  STREET                118.084      183.077                  132.662
# 2     ROW/TOWNHOUSE-OCC  118.084      183.077                  132.662
# 3     OTHER/RESIDENTIAL  118.084      183.077                  132.662
# 4  STREET                118.084      183.077                  132.662
#
#    Food_Beverage  Housing  Medical_Care  Other_Goods_Services  Recreation  \
# ...

# %%
df["Neighborhood"].unique()
# Out:
# array(['FEDERAL HILL', 'NEW NORTHWOOD', 'GRACELAND PARK',
#        'HOLLINS MARKET', 'JONESTOWN', 'WAVERLY', 'FRANKFORD',
#        'BELAIR-EDISON', 'HUNTING RIDGE', 'PATTERSON PLACE', 'WALTHERSON',
#        'ARMISTEAD GARDENS', 'IRVINGTON', 'CENTRAL PARK HEIGHTS',
#        'CHERRY HILL', 'GLEN', 'EDNOR GARDENS-LAKESIDE',
#        'TOWANDA-GRANTLEY', 'COLDSTREAM HOMESTEAD MONTEBELLO', 'LAKELAND',
#        'DOWNTOWN', 'HARLEM PARK', 'ABELL', 'BROOKLYN',
#        'MIDDLE BRANCH/REEDBIRD PARKS', 'GLENHAM-BELHAR', 'MONDAWMIN',
#        'PERKINS HOMES', 'INNER HARBOR', 'WOODMERE', 'CANTON', 'IDLEWOOD',
#        'HAMILTON HILLS', 'SAINT JOSEPHS', 'CENTRAL FOREST PARK',
#        'RICHNOR SPRINGS', 'ORANGEVILLE', 'BROADWAY EAST',
#        'MOUNT WASHINGTON', 'BREWERS HILL',
#        'CARROLL - CAMDEN INDUSTRIAL AREA', 'BRIDGEVIEW/GREENLAWN',
#        'MEDFIELD', 'WALBROOK', 'CARROLLTON RIDGE', 'LITTLE ITALY',
#        'CHINQUAPIN PARK', 'UPTON', 'GARWYN OAKS', 'LAURAVILLE',
# ...

# %%
enc = OrdinalEncoder()

# %%
print(enc)
# Out:
# OrdinalEncoder()

# %%
enc.fit_transform(df[["Neighborhood"]])
# Out:
# array([[157.],
#        [339.],
#        [183.],
#        ...,
#        [293.],
#        [ 65.],
#        [ 65.]])

# %%
df[["Neighborhood"]] = enc.fit_transform(df[["Neighborhood"]])

# %%
df.head()
# Out:
#    Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0        2012           12         31   26                      WHITE
# 1        2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2        2012           12         31   25                      WHITE
# 3        2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4        2012           12         31   25                      WHITE
#
#     District  Neighborhood               Premise  Apparel  Commodities  \
# 0   SOUTHERN         157.0                   BAR  118.084      183.077
# 1  NORTHEAST         339.0  STREET                118.084      183.077
# 2  SOUTHEAST         183.0     ROW/TOWNHOUSE-OCC  118.084      183.077
# 3   SOUTHERN         217.0     OTHER/RESIDENTIAL  118.084      183.077
# 4  SOUTHEAST         247.0  STREET                118.084      183.077
#
#    Education_Communication  Food_Beverage  Housing  Medical_Care  \
# ...

# %%
df[["Premise"]] = enc.fit_transform(df[["Premise"]])

# %%
df.head()
# Out:
#    Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0        2012           12         31   26                      WHITE
# 1        2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2        2012           12         31   25                      WHITE
# 3        2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4        2012           12         31   25                      WHITE
#
#     District  Neighborhood  Premise  Apparel  Commodities  \
# 0   SOUTHERN         157.0     13.0  118.084      183.077
# 1  NORTHEAST         339.0    138.0  118.084      183.077
# 2  SOUTHEAST         183.0    120.0  118.084      183.077
# 3   SOUTHERN         217.0     88.0  118.084      183.077
# 4  SOUTHEAST         247.0    138.0  118.084      183.077
#
#    Education_Communication  Food_Beverage  Housing  Medical_Care  \
# 0                  132.662        238.457  233.556       346.744
# ...

# %%
df["Description"].unique()
# Out:
# array(['LARCENY / BURGLARY / ROBBERY', 'COMMON ASSAULT / AGG. ASSAULT',
#        'HOMICIDE / SHOOTING', 'ARSON', 'RAPE'], dtype=object)

# %%
label_encoder = LabelEncoder()

# %%
print(label_encoder)
# Out:
# LabelEncoder()

# %%
df["Description"] = label_encoder.fit_transform(df["Description"])

# %%
df.head()
# Out:
#    Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0        2012           12         31   26                      WHITE
# 1        2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2        2012           12         31   25                      WHITE
# 3        2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4        2012           12         31   25                      WHITE
#
#     District  Neighborhood  Premise  Apparel  Commodities  \
# 0   SOUTHERN         157.0     13.0  118.084      183.077
# 1  NORTHEAST         339.0    138.0  118.084      183.077
# 2  SOUTHEAST         183.0    120.0  118.084      183.077
# 3   SOUTHERN         217.0     88.0  118.084      183.077
# 4  SOUTHEAST         247.0    138.0  118.084      183.077
#
#    Education_Communication  Food_Beverage  Housing  Medical_Care  \
# 0                  132.662        238.457  233.556       346.744
# ...

# %%
df["Description"].unique()
# Out:
# array([3, 1, 2, 0, 4])

# %%
df.to_csv('final_model6.csv', index = True)
