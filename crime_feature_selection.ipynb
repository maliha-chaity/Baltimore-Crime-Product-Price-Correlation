# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

import warnings
warnings.filterwarnings("ignore", category = FutureWarning)

df = pd.read_csv("final_dataset/crime_ordinal_encoded.csv")

# %%
df.head()
# Out:
#    Crime_Year  Crime_Month  Crime_Day  Age  Race  District  Neighborhood  \
# 0        2012           12         31   26     1         4           157
# 1        2012           12         31   34     0         0           339
# 2        2012           12         31   25     1         1           183
# 3        2012           12         31   48     0         4           217
# 4        2012           12         31   25     1         1           247
#
#    Premise  Apparel  Commodities  Education_Communication  Food_Beverage  \
# 0       13  118.084      183.077                  132.662        238.457
# 1      138  118.084      183.077                  132.662        238.457
# 2      120  118.084      183.077                  132.662        238.457
# 3       88  118.084      183.077                  132.662        238.457
# 4      138  118.084      183.077                  132.662        238.457
#
#    Housing  Medical_Care  Other_Goods_Services  Recreation  Services  \
# ...

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
