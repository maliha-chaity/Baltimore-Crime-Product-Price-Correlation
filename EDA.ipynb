# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

import warnings
warnings.filterwarnings("ignore", category = FutureWarning)

df = pd.read_csv("final_dataset/crime.csv")
# Out:
# C:\Users\14104\AppData\Local\Temp\ipykernel_14032\1809740632.py:11: DtypeWarning: Columns (10,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("final_dataset/crime.csv")

# %%
df.shape
# Out:
# (504379, 33)

# %%
df.loc[df['Description'] == "HOMICIDE", 'Description'] = "severe_crime"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "SHOOTING", 'Description'] = "severe_crime"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "ARSON", 'Description'] = "severe_crime"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "RAPE", 'Description'] = "severe_crime"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "LARCENY", 'Description'] = "moderate_crime"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "BURGLARY", 'Description'] = "moderate_crime"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "ROBBERY", 'Description'] = "moderate_crime"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "COMMON ASSAULT", 'Description'] = "moderate_crime"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "AGG. ASSAULT", 'Description'] = "moderate_crime"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "AUTO THEFT", 'Description'] = "moderate_crime"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.to_csv('binary_classification.csv', index = True)

# %%
# what kind of crime happened more in each "District" in each year

# crime in each "District" in 2023
cri_dis = df[(df["Crime_Year"] == 2023) & (df["Description"]) & (df["District"])]
print(cri_dis["Crime_Year"], cri_dis["Description"], cri_dis["District"])

# categories of crimes in 2023
cat_des = cri_dis["Description"].value_counts()
print("Categories of crimes in in 2023:", cat_des)

# number of crimes in each district in 2023
cat_dis = cri_dis["District"].value_counts()
print("number of crimes in each district in 2023:", cat_des)

descript = df[(df["Description"] == "LARCENY") & (df["Description"] == "AUTO THEFT")]

# %%
df.loc[df['Description'] == "LARCENY", 'Description'] = "LARCENY / AUTO THEFT"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "AUTO THEFT", 'Description'] = "LARCENY / AUTO THEFT"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "HOMICIDE", 'Description'] = "HOMICIDE / SHOOTING"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "SHOOTING", 'Description'] = "HOMICIDE / SHOOTING"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "BURGLARY", 'Description'] = "BURGLARY / ROBBERY"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "ROBBERY", 'Description'] = "BURGLARY / ROBBERY"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "COMMON ASSAULT", 'Description'] = "COMMON ASSAULT / AGG. ASSAULT"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "AGG. ASSAULT", 'Description'] = "COMMON ASSAULT / AGG. ASSAULT"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "LARCENY / AUTO THEFT", 'Description'] = "LARCENY / BURGLARY / ROBBERY"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.loc[df['Description'] == "BURGLARY / ROBBERY", 'Description'] = "LARCENY / BURGLARY / ROBBERY"
df
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 291595        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 291596        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 291597        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 291598        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 291599        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.to_csv('final_model5.csv', index = True)

# %%
corr = df.corr()
corr
# Out:
#                          Crime_Year  Crime_Month  Crime_Day       Age  \
# Crime_Year                 1.000000    -0.059993  -0.005152 -0.004064
# Crime_Month               -0.059993     1.000000  -0.002600  0.013069
# Crime_Day                 -0.005152    -0.002600   1.000000 -0.003516
# Age                       -0.004064     0.013069  -0.003516  1.000000
# Race                      -0.038495     0.020659   0.005765  0.079812
# District                   0.032643    -0.005912  -0.002663  0.005867
# Neighborhood               0.018726     0.002664   0.000318  0.006410
# Premise                   -0.028206     0.014168   0.002414  0.018256
# Apparel                    0.231201     0.157141  -0.007759 -0.003006
# Commodities                0.467978    -0.010092  -0.001102 -0.005785
# Education_Communication    0.978863     0.017802  -0.005884 -0.005283
# Food_Beverage              0.904185     0.016150  -0.005644 -0.005519
# ...

# %%
corr = df.corr()
plt.figure(figsize = (15, 15))
sns.heatmap(corr, annot = True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
df.columns.values
# Out:
# array(['Crime_Year', 'Crime_Month', 'Crime_Day', 'Age', 'Race',
#        'District', 'Neighborhood', 'Premise', 'Apparel', 'Commodities',
#        'Education_Communication', 'Food_Beverage', 'Housing',
#        'Medical_Care', 'Other_Goods_Services', 'Recreation', 'Services',
#        'Transportation', 'All_Items', 'Description'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291600 entries, 0 to 291599
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Crime_Year               291600 non-null  int64
#  1   Crime_Month              291600 non-null  int64
#  2   Crime_Day                291600 non-null  int64
#  3   Age                      291600 non-null  int64
#  4   Race                     291600 non-null  object
#  5   District                 291600 non-null  object
#  6   Neighborhood             291600 non-null  object
#  7   Premise                  291600 non-null  object
#  8   Apparel                  291600 non-null  float64
#  9   Commodities              291600 non-null  float64
#  10  Education_Communication  291600 non-null  float64
#  11  Food_Beverage            291600 non-null  float64
#  12  Housing                  291600 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Crime_Year                 0
# Crime_Month                0
# Crime_Day                  0
# Age                        0
# Race                       0
# District                   0
# Neighborhood               0
# Premise                    0
# Apparel                    0
# Commodities                0
# Education_Communication    0
# Food_Beverage              0
# Housing                    0
# Medical_Care               0
# Other_Goods_Services       0
# Recreation                 0
# Services                   0
# Transportation             0
# All_Items                  0
# Description                0
# dtype: int64

# %%
# finding categories for "Race" column

df['Race'].value_counts()
# Out:
# BLACK_OR_AFRICAN_AMERICAN                    263378
# UNKNOWN                                      123374
# WHITE                                        105817
# ASIAN                                           680
# AMERICAN_INDIAN_OR_ALASKA_NATIVE                635
# NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER       211
# Name: Race, dtype: int64

# %%
# finding categories for "District" column

df['District'].value_counts()
# Out:
# NORTHEAST    73859
# SOUTHEAST    68188
# CENTRAL      57603
# SOUTHERN     55404
# NORTHERN     53721
# SOUTHWEST    49908
# NORTHWEST    49890
# EASTERN      42847
# WESTERN      39267
# SD5            875
# Name: District, dtype: int64

# %%
# finding categories for "Neighborhood" column

df['Neighborhood'].value_counts()
# Out:
# DOWNTOWN                    15684
# FRANKFORD                   10867
# BELAIR-EDISON                9740
# BROOKLYN                     8219
# SANDTOWN-WINCHESTER          6643
#                             ...
# Gwynns Falls/Leakin Park        2
# Bellona-Gittings                2
# Herring Run Park                1
# DUNDALK MARINE TERMINAL         1
# Greenmount Cemetery             1
# Name: Neighborhood, Length: 552, dtype: int64

# %%
# finding categories for "Premise" column

df['Premise'].value_counts()
# Out:
# STREET                  144231
# ROW/TOWNHOUSE-OCC        85130
# STREET                   20129
# APT/CONDO - OCCUPIED     18606
# OTHER - INSIDE           15742
#                          ...
# BAKERY                       1
# MARKET STALLS                1
# RENTAL/VIDEO STORE           1
# DOCTORS OFFICE               1
# FIRE DEPARTMENT              1
# Name: Premise, Length: 166, dtype: int64

# %%
# finding categories for "Description" column

df['Description'].value_counts()
# Out:
# LARCENY                 112972
# COMMON ASSAULT           91166
# BURGLARY                 68745
# LARCENY FROM AUTO        64875
# AGG. ASSAULT             57683
# AUTO THEFT               43077
# ROBBERY                  40900
# SHOOTING                  6070
# ROBBERY - COMMERCIAL      5480
# ROBBERY - CARJACKING      4561
# HOMICIDE                  3353
# RAPE                      3318
# ARSON                     2179
# Name: Description, dtype: int64

# %%
# number of larceny caused by black people

ls = df[(df["Description"] == 'LARCENY') & (df["Race"] == "BLACK_OR_AFRICAN_AMERICAN")]
des_lc = ls["Description"].count()
#print("number of larceny:", des_lc)

ls = df[(df["Description"] == 'LARCENY FROM AUTO') & (df["Race"] == "BLACK_OR_AFRICAN_AMERICAN")]
des_lc_auto = ls["Description"].count()
#print("number of larceny:", des_lc_auto)

ls = df[(df["Description"] == 'AUTO THEFT') & (df["Race"] == "BLACK_OR_AFRICAN_AMERICAN")]
des_lc_theft = ls["Description"].count()
#print("number of larceny:", des_lc_theft)

total_lc = des_lc + des_lc_auto + des_lc_theft;
print("total number or larceny caused by black people: ", total_lc)

# number of larceny caused by white people

ls = df[(df["Description"] == 'LARCENY') & (df["Race"] == "WHITE")]
des_lc = ls["Description"].count()
#print("number of larceny:", des_lc)

ls = df[(df["Description"] == 'LARCENY FROM AUTO') & (df["Race"] == "WHITE")]
des_lc_auto = ls["Description"].count()
#print("number of larceny:", des_lc_auto)

ls = df[(df["Description"] == 'AUTO THEFT') & (df["Race"] == "WHITE")]
des_lc_theft = ls["Description"].count()
#print("number of larceny:", des_lc_theft)

total_lc = des_lc + des_lc_auto + des_lc_theft;
print("total number or larceny caused by white people: ", total_lc)

# number of assault caused by black people

ls = df[(df["Description"] == 'COMMON ASSAULT') & (df["Race"] == "BLACK_OR_AFRICAN_AMERICAN")]
des_lc = ls["Description"].count()
#print("number of larceny:", des_lc)

ls = df[(df["Description"] == 'AGG. ASSAULT') & (df["Race"] == "BLACK_OR_AFRICAN_AMERICAN")]
des_lc_auto = ls["Description"].count()
#print("number of larceny:", des_lc_auto)

total_lc = des_lc + des_lc_auto;
print("total number or assault caused by black people: ", total_lc)

# number of assault caused by white people

ls = df[(df["Description"] == 'COMMON ASSAULT') & (df["Race"] == "WHITE")]
des_lc = ls["Description"].count()
#print("number of larceny:", des_lc)

ls = df[(df["Description"] == 'AGG. ASSAULT') & (df["Race"] == "WHITE")]
des_lc_auto = ls["Description"].count()
#print("number of larceny:", des_lc_auto)

total_lc = des_lc + des_lc_auto;
print("total number or assault caused by white people: ", total_lc)

# number of burglary caused by black people

ls = df[(df["Description"] == 'BURGLARY') & (df["Race"] == "BLACK_OR_AFRICAN_AMERICAN")]
des_lc = ls["Description"].count()

print("total number or burglary caused by black people: ", des_lc)

# number of burglary caused by white people

ls = df[(df["Description"] == 'BURGLARY') & (df["Race"] == "WHITE")]
des_lc = ls["Description"].count()

print("total number or burglary caused by white people: ", des_lc)

# number of robbery caused by black people

ls = df[(df["Description"] == 'ROBBERY') & (df["Race"] == "BLACK_OR_AFRICAN_AMERICAN")]
des_lc = ls["Description"].count()
#print("number of larceny:", des_lc)

ls = df[(df["Description"] == 'ROBBERY - COMMERCIAL') & (df["Race"] == "BLACK_OR_AFRICAN_AMERICAN")]
des_lc_auto = ls["Description"].count()
#print("number of larceny:", des_lc_auto)

ls = df[(df["Description"] == 'ROBBERY - CARJACKING') & (df["Race"] == "BLACK_OR_AFRICAN_AMERICAN")]
des_lc_theft = ls["Description"].count()
#print("number of larceny:", des_lc_theft)

total_lc = des_lc + des_lc_auto + des_lc_theft;
print("total number or robbery caused by black people: ", total_lc)

# number of robbery caused by white people

ls = df[(df["Description"] == 'ROBBERY') & (df["Race"] == "WHITE")]
des_lc = ls["Description"].count()
#print("number of larceny:", des_lc)

ls = df[(df["Description"] == 'ROBBERY - COMMERCIAL') & (df["Race"] == "WHITE")]
des_lc_auto = ls["Description"].count()
#print("number of larceny:", des_lc_auto)

ls = df[(df["Description"] == 'ROBBERY - CARJACKING') & (df["Race"] == "WHITE")]
des_lc_theft = ls["Description"].count()
#print("number of larceny:", des_lc_theft)

total_lc = des_lc + des_lc_auto + des_lc_theft;
print("total number or robbery caused by white people: ", total_lc)

# number of shooting caused by black people

ls = df[(df["Description"] == 'SHOOTING') & (df["Race"] == "BLACK_OR_AFRICAN_AMERICAN")]
des_lc = ls["Description"].count()

print("total number or shooting caused by black people: ", des_lc)

# number of shooting caused by white people

ls = df[(df["Description"] == 'SHOOTING') & (df["Race"] == "WHITE")]
des_lc = ls["Description"].count()

print("total number or shooting caused by white people: ", des_lc)

# number of homicide caused by black people

ls = df[(df["Description"] == 'HOMICIDE') & (df["Race"] == "BLACK_OR_AFRICAN_AMERICAN")]
des_lc = ls["Description"].count()

print("total number or homicide caused by black people: ", des_lc)

# number of homicide caused by white people

ls = df[(df["Description"] == 'HOMICIDE') & (df["Race"] == "WHITE")]
des_lc = ls["Description"].count()

print("total number or homicide caused by white people: ", des_lc)

# number of rape caused by black people

ls = df[(df["Description"] == 'RAPE') & (df["Race"] == "BLACK_OR_AFRICAN_AMERICAN")]
des_lc = ls["Description"].count()

print("total number or rape caused by black people: ", des_lc)

# number of rape caused by white people

ls = df[(df["Description"] == 'RAPE') & (df["Race"] == "WHITE")]
des_lc = ls["Description"].count()

print("total number or rape caused by white people: ", des_lc)

# number of arson caused by black people

ls = df[(df["Description"] == 'ARSON') & (df["Race"] == "BLACK_OR_AFRICAN_AMERICAN")]
des_lc = ls["Description"].count()

print("total number or arson caused by black people: ", des_lc)

# number of arson caused by white people

ls = df[(df["Description"] == 'ARSON') & (df["Race"] == "WHITE")]
des_lc = ls["Description"].count()

print("total number or arson caused by white people: ", des_lc)
# Out:
# total number or larceny caused by black people:  94414
# total number or larceny caused by white people:  53974
# total number or assault caused by black people:  104993
# total number or assault caused by white people:  23914
# total number or burglary caused by black people:  28963
# total number or burglary caused by white people:  15127
# total number or robbery caused by black people:  23096
# total number or robbery caused by white people:  11358
# total number or shooting caused by black people:  5673
# total number or shooting caused by white people:  256
# total number or homicide caused by black people:  3105
# total number or homicide caused by white people:  177
# total number or rape caused by black people:  2084
# total number or rape caused by white people:  800
# total number or arson caused by black people:  1050
# total number or arson caused by white people:  211

# %%
# number of larceny caused by male

ls = df[(df["Description"] == 'LARCENY') & (df["Gender"] == "M")]
des_lc = ls["Description"].count()
#print("number of larceny:", des_lc)

ls = df[(df["Description"] == 'LARCENY FROM AUTO') & (df["Gender"] == "M")]
des_lc_auto = ls["Description"].count()
#print("number of larceny:", des_lc_auto)

ls = df[(df["Description"] == 'AUTO THEFT') & (df["Gender"] == "M")]
des_lc_theft = ls["Description"].count()
#print("number of larceny:", des_lc_theft)

total_lc = des_lc + des_lc_auto + des_lc_theft;
print("total number or larceny caused by male: ", total_lc)

# number of larceny caused by female

ls = df[(df["Description"] == 'LARCENY') & (df["Gender"] == "F")]
des_lc = ls["Description"].count()
#print("number of larceny:", des_lc)

ls = df[(df["Description"] == 'LARCENY FROM AUTO') & (df["Gender"] == "F")]
des_lc_auto = ls["Description"].count()
#print("number of larceny:", des_lc_auto)

ls = df[(df["Description"] == 'AUTO THEFT') & (df["Gender"] == "F")]
des_lc_theft = ls["Description"].count()
#print("number of larceny:", des_lc_theft)

total_lc = des_lc + des_lc_auto + des_lc_theft;
print("total number or larceny caused by female: ", total_lc)

# number of assault caused by male

ls = df[(df["Description"] == 'COMMON ASSAULT') & (df["Gender"] == "M")]
des_lc = ls["Description"].count()
#print("number of larceny:", des_lc)

ls = df[(df["Description"] == 'AGG. ASSAULT') & (df["Gender"] == "M")]
des_lc_auto = ls["Description"].count()
#print("number of larceny:", des_lc_auto)

total_lc = des_lc + des_lc_auto;
print("total number or assault caused by male: ", total_lc)

# number of assault caused by female

ls = df[(df["Description"] == 'COMMON ASSAULT') & (df["Gender"] == "F")]
des_lc = ls["Description"].count()
#print("number of larceny:", des_lc)

ls = df[(df["Description"] == 'AGG. ASSAULT') & (df["Gender"] == "F")]
des_lc_auto = ls["Description"].count()
#print("number of larceny:", des_lc_auto)

total_lc = des_lc + des_lc_auto;
print("total number or assault caused by female: ", total_lc)

# number of burglary caused by male

ls = df[(df["Description"] == 'BURGLARY') & (df["Gender"] == "M")]
des_lc = ls["Description"].count()

print("total number or burglary caused by male: ", des_lc)

# number of burglary caused by female

ls = df[(df["Description"] == 'BURGLARY') & (df["Gender"] == "F")]
des_lc = ls["Description"].count()

print("total number or burglary caused by female: ", des_lc)

# number of robbery caused by male

ls = df[(df["Description"] == 'ROBBERY') & (df["Gender"] == "M")]
des_lc = ls["Description"].count()
#print("number of larceny:", des_lc)

ls = df[(df["Description"] == 'ROBBERY - COMMERCIAL') & (df["Gender"] == "M")]
des_lc_auto = ls["Description"].count()
#print("number of larceny:", des_lc_auto)

ls = df[(df["Description"] == 'ROBBERY - CARJACKING') & (df["Gender"] == "M")]
des_lc_theft = ls["Description"].count()
#print("number of larceny:", des_lc_theft)

total_lc = des_lc + des_lc_auto + des_lc_theft;
print("total number or robbery caused by male: ", total_lc)

# number of robbery caused by female

ls = df[(df["Description"] == 'ROBBERY') & (df["Gender"] == "F")]
des_lc = ls["Description"].count()
#print("number of larceny:", des_lc)

ls = df[(df["Description"] == 'ROBBERY - COMMERCIAL') & (df["Gender"] == "F")]
des_lc_auto = ls["Description"].count()
#print("number of larceny:", des_lc_auto)

ls = df[(df["Description"] == 'ROBBERY - CARJACKING') & (df["Gender"] == "F")]
des_lc_theft = ls["Description"].count()
#print("number of larceny:", des_lc_theft)

total_lc = des_lc + des_lc_auto + des_lc_theft;
print("total number or robbery caused by male: ", total_lc)

# number of shooting caused by male

sh = df[(df["Description"] == 'SHOOTING') & (df["Gender"] == "Male")]
des_sh = ls["Description"].count()

print("total number or shooting caused by male: ", des_sh)

# number of shooting caused by female

sh = df[(df["Description"] == 'SHOOTING') & (df["Gender"] == "Female")]
des_sh = ls["Description"].count()

print("total number or shooting caused by female: ", des_sh)

# number of homicide caused by male

hm = df[(df["Description"] == 'HOMICIDE') & (df["Gender"] == "Male")]
des_hm = ls["Description"].count()

print("total number or homicide caused by male: ", des_hm)

# number of homicide caused by female

hm = df[(df["Description"] == 'HOMICIDE') & (df["Gender"] == "Female")]
des_hm = ls["Description"].count()

print("total number or homicide caused by female: ", des_hm)

# number of rape caused by male

ls = df[(df["Description"] == 'RAPE') & (df["Gender"] == "M")]
des_lc = ls["Description"].count()

print("total number or rape caused by male: ", des_lc)

# number of rape caused by female

ls = df[(df["Description"] == 'RAPE') & (df["Gender"] == "F")]
des_lc = ls["Description"].count()

print("total number or rape caused by female: ", des_lc)

# number of arson caused by male

ls = df[(df["Description"] == 'ARSON') & (df["Gender"] == "M")]
des_lc = ls["Description"].count()

print("total number or arson caused by male: ", des_lc)

# number of arson caused by female

ls = df[(df["Description"] == 'ARSON') & (df["Gender"] == "F")]
des_lc = ls["Description"].count()

print("total number or arson caused by female: ", des_lc)
# Out:
# total number or larceny caused by male:  80326
# total number or larceny caused by female:  86866
# total number or assault caused by male:  60715
# total number or assault caused by female:  78679
# total number or burglary caused by male:  23731
# total number or burglary caused by female:  25489
# total number or robbery caused by male:  25566
# total number or robbery caused by male:  14743
# total number or shooting caused by male:  1317
# total number or shooting caused by female:  1317
# total number or homicide caused by male:  1317
# total number or homicide caused by female:  1317
# total number or rape caused by male:  217
# total number or rape caused by female:  2919
# total number or arson caused by male:  687
# total number or arson caused by female:  725

# %%
# number of BURGLARY in 2023

ls = df[(df["Crime_Year"] == 2023) & (df["Description"] == "BURGLARY")]
des_ls = ls["Description"].count()
print("number of burglary in 2023:", des_ls)

# percentage of BURGLARY in 2023
total_23 = df[(df["Crime_Year"] == 2023)]
rows = total_23.index
rws = len(rows)

per_la = (des_ls*100) / rws
print("percentage of burglary in 2023:", per_la)

# %%
# finding categories for "Age" column

df['Age'].value_counts()
# Out:
#  27.0      13086
#  28.0      12870
#  26.0      12668
#  29.0      12653
#  25.0      12250
#            ...
# -2977.0        1
# -7979.0        1
# -972.0         1
#  194.0         1
#  124.0         1
# Name: Age, Length: 173, dtype: int64

# %%
df.loc[df['Age'] > 70, 'Age'] = 27

# %%
df.loc[df['Age'] < 15, 'Age'] = 15

# %%
# finding categories for "Age" column

df['Age'].value_counts()
# Out:
# 27.0    21130
# 15.0    12023
# 28.0    10292
# 26.0    10228
# 29.0    10182
# 30.0     9841
# 25.0     9776
# 24.0     9422
# 31.0     9391
# 32.0     9182
# 23.0     8744
# 33.0     8336
# 34.0     8165
# 35.0     7808
# 22.0     7736
# 36.0     7207
# 37.0     6920
# 21.0     6753
# 38.0     6357
# 39.0     6035
# 40.0     5690
# 20.0     5646
# 41.0     5424
# 42.0     5300
# 43.0     5175
# 44.0     5031
# 46.0     5030
# 45.0     4990
# 49.0     4935
# 50.0     4919
# 48.0     4901
# 52.0     4890
# 51.0     4880
# 47.0     4811
# 53.0     4716
# 54.0     4666
# 19.0     4617
# 55.0     4378
# 56.0     4340
# 57.0     4283
# 58.0     3888
# 18.0     3756
# 59.0     3550
# 60.0     3549
# 17.0     3136
# 61.0     3073
# 62.0     2950
# 16.0     2878
# 63.0     2671
# 64.0     2350
# 65.0     2264
# 66.0     2063
# 67.0     1840
# 68.0     1751
# 69.0     1499
# 70.0     1297
# Name: Age, dtype: int64

# %%
df.to_csv('final_model1.csv', index = True)

# %%
#exclude any rows with missing data

df = df.dropna() 
print(df)
# Out:
#         Crime_Year  Crime_Month  Crime_Day  Age                       Race  \
# 0             2012           12         31   26                      WHITE
# 1             2012           12         31   34  BLACK_OR_AFRICAN_AMERICAN
# 2             2012           12         31   25                      WHITE
# 3             2012           12         31   48  BLACK_OR_AFRICAN_AMERICAN
# 4             2012           12         31   25                      WHITE
# ...            ...          ...        ...  ...                        ...
# 326660        2022           11          1   22  BLACK_OR_AFRICAN_AMERICAN
# 326661        2022           11          1   40  BLACK_OR_AFRICAN_AMERICAN
# 326662        2022           11          1   49  BLACK_OR_AFRICAN_AMERICAN
# 326663        2022           11          1   53  BLACK_OR_AFRICAN_AMERICAN
# 326664        2022           11          1   23  BLACK_OR_AFRICAN_AMERICAN
#
# ...

# %%
df.isnull().sum()
# Out:
# Crime_Year                 0
# Crime_Month                0
# Crime_Day                  0
# Age                        0
# Race                       0
# District                   0
# Neighborhood               0
# Premise                    0
# Apparel                    0
# Commodities                0
# Education_Communication    0
# Food_Beverage              0
# Housing                    0
# Medical_Care               0
# Other_Goods_Services       0
# Recreation                 0
# Services                   0
# Transportation             0
# All_Items                  0
# Description                0
# dtype: int64

# %%
df.to_csv('modifiedGDP.csv', index = True)

# %%
# finding categories for "Race" column

df['Race'].value_counts()
# Out:
# BLACK_OR_AFRICAN_AMERICAN                    215974
# WHITE                                         84950
# ASIAN                                           511
# AMERICAN_INDIAN_OR_ALASKA_NATIVE                451
# NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER       111
# Name: Race, dtype: int64

# %%
# finding categories for "Age" column

df['Age'].value_counts()
# Out:
# 27.0    25329
# 15.0    15931
# 28.0    12870
# 26.0    12668
# 29.0    12653
# 25.0    12250
# 30.0    12225
# 24.0    11815
# 31.0    11626
# 32.0    11410
# 23.0    10977
# 33.0    10355
# 34.0    10105
# 22.0     9708
# 35.0     9585
# 36.0     8951
# 21.0     8589
# 37.0     8558
# 38.0     7947
# 39.0     7421
# 20.0     7152
# 40.0     7060
# 41.0     6696
# 42.0     6506
# 43.0     6436
# 44.0     6156
# 45.0     6086
# 46.0     6028
# 50.0     5964
# 19.0     5889
# 49.0     5868
# 48.0     5855
# 52.0     5830
# 51.0     5824
# 47.0     5793
# 53.0     5680
# 54.0     5538
# 55.0     5233
# 56.0     5181
# 57.0     5067
# 18.0     4865
# 58.0     4680
# 59.0     4216
# 60.0     4203
# 17.0     3993
# 61.0     3720
# 16.0     3630
# 62.0     3538
# 63.0     3176
# 64.0     2832
# 65.0     2687
# 66.0     2443
# 67.0     2149
# 68.0     2067
# 69.0     1779
# 70.0     1524
# Name: Age, dtype: int64

# %%
df.to_csv('modifiedGDP.csv', index = True)

# %%
df1.to_csv('modifiedGDP.csv', index = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-5ddaee6a4db9> in <module>
# ----> 1 df1.to_csv('modifiedGDP.csv', index = True)
#
# AttributeError: 'int' object has no attribute 'to_csv'

# %%
df.columns.values
# Out:
# array(['Crime_Year', 'Crime_Month', 'Crime_Day', 'Age', 'Race',
#        'District', 'Apparel', 'Commodities', 'Education_Communication',
#        'Food_Beverage', 'Housing', 'Medical_Care', 'Other_Goods_Services',
#        'Recreation', 'Services', 'Transportation', 'All_Items',
#        'Description'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301997 entries, 0 to 301996
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Crime_Year               301997 non-null  int64
#  1   Crime_Month              301997 non-null  int64
#  2   Crime_Day                301997 non-null  int64
#  3   Age                      301997 non-null  int64
#  4   Race                     301997 non-null  object
#  5   District                 301997 non-null  object
#  6   Apparel                  301997 non-null  float64
#  7   Commodities              301997 non-null  float64
#  8   Education_Communication  301997 non-null  float64
#  9   Food_Beverage            301997 non-null  float64
#  10  Housing                  301997 non-null  float64
#  11  Medical_Care             301997 non-null  float64
#  12  Other_Goods_Services     301997 non-null  float64
# ...

# %%
df.isnull().sum()

# drop columns for so many null values - ethnicity, post
# Out:
# Crime_Year                 0
# Crime_Month                0
# Crime_Day                  0
# Age                        0
# Race                       0
# District                   0
# Apparel                    0
# Commodities                0
# Education_Communication    0
# Food_Beverage              0
# Housing                    0
# Medical_Care               0
# Other_Goods_Services       0
# Recreation                 0
# Services                   0
# Transportation             0
# All_Items                  0
# Description                0
# dtype: int64

# %%
# detecting outliers for age

sns.boxplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
# number of people with different age range. It seems majority people who caused crime where aged between 26 to 35. People 
# with age range 5 and 25 comes to the second place.

ab = df[(df['Age'] > 75)].shape[0]
print("People with Age greater than 75 are:", ab)

cd = df[(df['Age'] >= 60) & (df['Age'] <= 75)].shape[0]
print("People with Age in between 60 and 70 are:", cd)

ef = df[(df['Age'] >= 46) & (df['Age'] <= 60)].shape[0]
print("People with Age in between 46 and 60 are:", ef)

gh = df[(df['Age'] >= 36) & (df['Age'] <= 45)].shape[0]
print("People with Age in between 36 and 45 are:", gh)

ij = df[(df['Age'] >= 26) & (df['Age'] <= 35)].shape[0]
print("People with Age in between 26 and 35 are:", ij)

kl = df[(df['Age'] >= 5) & (df['Age'] <= 25)].shape[0]
print("People with Age in between 5 and 25 are:", kl)
# Out:
# People with Age greater than 75 are: 0
# People with Age in between 60 and 70 are: 56705
# People with Age in between 46 and 60 are: 53438
# People with Age in between 36 and 45 are: 45747
# People with Age in between 26 and 35 are: 85079
# People with Age in between 5 and 25 are: 61028

# %%
# at which time crime occured the most (manipulate the year, month, day, time data)

# %%
# finding categories for "Description" column

df['Description'].value_counts()
# Out:
# COMMON ASSAULT          62953
# LARCENY                 52479
# AGG. ASSAULT            39604
# BURGLARY                39358
# LARCENY FROM AUTO       39012
# AUTO THEFT              28636
# ROBBERY                 25052
# SHOOTING                 5749
# HOMICIDE                 3001
# ROBBERY - CARJACKING     2702
# RAPE                     2274
# ARSON                    1052
# ROBBERY - COMMERCIAL      125
# Name: Description, dtype: int64

# %%
# find categories in "Race" column. Black or African Americans committed most number of crimes. White are in 
# the scond place.

df['Race'].value_counts()
# Out:
# BLACK_OR_AFRICAN_AMERICAN                    215974
# WHITE                                         84950
# ASIAN                                           511
# AMERICAN_INDIAN_OR_ALASKA_NATIVE                451
# NATIVE_HAWAIIAN_OR_OTHER_PACIFIC_ISLANDER       111
# Name: Race, dtype: int64

# %%
# find categories in "District" column. Result shows that, crime occured in pretty much every district parallely.

df['District'].value_counts()
# Out:
# NORTHEAST    48525
# SOUTHEAST    34618
# CENTRAL      33914
# NORTHERN     33041
# SOUTHERN     32617
# NORTHWEST    32119
# SOUTHWEST    32014
# EASTERN      27926
# WESTERN      26729
# SD5            494
# Name: District, dtype: int64

# %%
--------------------------------------------------------------------------------

# %%
# female attackers caused what kind of crime most in each year

# crimes caused by female in 2023
f_des = df[(df["Gender"] == "F") & (df["Description"]) & (df["Race"])]
print(f_des["Gender"], f_des["Description"], f_des["Race"])
#print(len(f_des))

print("Category of crimes caused by female in 2023:")
print(f_des["Description"].value_counts())

print(" categories of Race of female who caused crime in 2023:")
print(f_des["Race"].value_counts())
# Out:
# 0         F
# 1         F
# 10        F
# 15        F
# 16        F
#          ..
# 504364    F
# 504365    F
# 504368    F
# 504374    F
# 504377    F
# Name: Gender, Length: 208373, dtype: object 0                   LARCENY
# 1            COMMON ASSAULT
# 10        LARCENY FROM AUTO
# 15                  LARCENY
# 16                  LARCENY
#                 ...
# 504364           AUTO THEFT
# 504365       COMMON ASSAULT
# 504368           AUTO THEFT
# 504374       COMMON ASSAULT
# 504377             BURGLARY
# Name: Description, Length: 208373, dtype: object 0                             WHITE
# 1         BLACK_OR_AFRICAN_AMERICAN
# 10        BLACK_OR_AFRICAN_AMERICAN
# 15                            WHITE
# 16                            WHITE
#                     ...
# 504364                        WHITE
# 504365    BLACK_OR_AFRICAN_AMERICAN
# 504368    BLACK_OR_AFRICAN_AMERICAN
# 504374    BLACK_OR_AFRICAN_AMERICAN
# 504377    BLACK_OR_AFRICAN_AMERICAN
# ...

# %%
----------------------------------------------------------------------

# %%
# male attackers caused what kind of crime most in each year

# crimes caused by male in 2023
m_des = df[(df["Gender"] == "M") & (df["Description"]) & (df["Race"])]
print(m_des["Gender"], m_des["Description"], m_des["Race"])
#print(len(f_des))

print("Category of crimes caused by male in 2023:")
print(m_des["Description"].value_counts())

print(" categories of Race of male who caused crime in 2023:")
print(m_des["Race"].value_counts())
# Out:
# 2         M
# 3         M
# 4         M
# 5         M
# 6         M
#          ..
# 504370    M
# 504371    M
# 504372    M
# 504373    M
# 504376    M
# Name: Gender, Length: 189486, dtype: object 2                   LARCENY
# 3                  BURGLARY
# 4         LARCENY FROM AUTO
# 5                   ROBBERY
# 6                  BURGLARY
#                 ...
# 504370       COMMON ASSAULT
# 504371       COMMON ASSAULT
# 504372       COMMON ASSAULT
# 504373         AGG. ASSAULT
# 504376           AUTO THEFT
# Name: Description, Length: 189486, dtype: object 2                             WHITE
# 3         BLACK_OR_AFRICAN_AMERICAN
# 4                             WHITE
# 5         BLACK_OR_AFRICAN_AMERICAN
# 6         BLACK_OR_AFRICAN_AMERICAN
#                     ...
# 504370                        WHITE
# 504371                        WHITE
# 504372                        WHITE
# 504373    BLACK_OR_AFRICAN_AMERICAN
# 504376    BLACK_OR_AFRICAN_AMERICAN
# ...

# %%
# TRY TO FILL UP THE FIRST 50% NULL WITH MALE AND LAST 50% NULL WITH FEMALE IN "GENDER" COLUMN. Also find out gender 
# information for every year.
--------------------------------------------------------------------------------

# %%
# what kind of crime happened more in each "District" in each year

# crime in each "District" in 2023
cri_dis = df[(df["Crime_Year"] == 2023) & (df["Description"]) & (df["District"])]
print(cri_dis["Crime_Year"], cri_dis["Description"], cri_dis["District"])

# categories of crimes in 2023
cat_des = cri_dis["Description"].value_counts()
print("Categories of crimes in in 2023:", cat_des)

# number of crimes in each district in 2023
cat_dis = cri_dis["District"].value_counts()
print("number of crimes in each district in 2023:", cat_des)
# Out:
# 500199    2023
# 500200    2023
# 500201    2023
# 500202    2023
# 500203    2023
#           ...
# 504374    2023
# 504375    2023
# 504376    2023
# 504377    2023
# 504378    2023
# Name: Crime_Year, Length: 4170, dtype: int64 500199      AGG. ASSAULT
# 500200        AUTO THEFT
# 500201          BURGLARY
# 500202    COMMON ASSAULT
# 500203    COMMON ASSAULT
#                ...
# 504374    COMMON ASSAULT
# 504375           LARCENY
# 504376        AUTO THEFT
# 504377          BURGLARY
# 504378          SHOOTING
# Name: Description, Length: 4170, dtype: object 500199      CENTRAL
# 500200    NORTHEAST
# 500201      CENTRAL
# 500202     NORTHERN
# 500203    SOUTHEAST
#             ...
# 504374    SOUTHEAST
# 504375     NORTHERN
# 504376    NORTHEAST
# 504377    NORTHWEST
# 504378      WESTERN
# Name: District, Length: 4170, dtype: object
# Categories of crimes in each district in 2023: COMMON ASSAULT          1056
# LARCENY                  982
# AGG. ASSAULT             484
# ...

# %%
# do the same thing for "Neighborhood" and each year
---------------------------------------------------------------------
